# %% [markdown]
# # Unified Perception Framework - Demo
#
# This notebook demonstrates the unified perception framework for multimodal semantic segmentation.

# %%
# Import libraries
import torch
import matplotlib.pyplot as plt
from src.models.unified_model import UnifiedPerceptionModel

# %% [markdown]
# ## 1. Load Model
#
# Load the pre-trained unified perception model.

# %%
# Initialize model
model = UnifiedPerceptionModel(num_classes=19, feature_dim=256)
print('Model loaded successfully!')
